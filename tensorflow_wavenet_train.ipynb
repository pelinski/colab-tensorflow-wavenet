# %% [markdown]
# <a href="https://colab.research.google.com/github/pelinski/colab-tensorflow-wavenet/blob/master/tensorflow_wavenet_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
root_dir = "/content/drive/MyDrive/WAVENETS/tensorflow-wavenet"
data_dir = "/content/drive/MyDrive/WAVENETS/DATA"
silence_th = 0.1 # modify according to your dataset
d_cp = 500 # checkpoint every

# %% [markdown]
# # drive + libraries

# %%
# mount your google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# install dependencies
! pip install librosa==0.6.3
! pip install tensorflow-gpu==1.15
! pip install numba==0.48
# %tensorflow_version 1.x
# Out:
# ...
#      |████████████████████████████████| 1.6MB 5.9MB/s
# ...
#   Created wheel for librosa: filename=librosa-0.6.3-cp37-none-any.whl size=1573318 sha256=ab6da6022fe576cd24568f83f5f9aab5ccb8164e3b24a48d1c8908d478f02b97
#   Stored in directory: /root/.cache/pip/wheels/ce/49/68/87ba660f30e3977f0778e39ee2e944629cd37c2a0ce41f9ff1
# Successfully built librosa
# ...
#   Found existing installation: librosa 0.8.0
#     Uninstalling librosa-0.8.0:
#       Successfully uninstalled librosa-0.8.0
# ...
#      |████████████████████████████████| 411.5MB 43kB/s
# ...
#      |████████████████████████████████| 51kB 6.9MB/s
# ...
#      |████████████████████████████████| 512kB 51.1MB/s
# ...
#      |████████████████████████████████| 3.8MB 51.2MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp37-none-any.whl size=7540 sha256=47712789e5512c76d677b32524cc730409d70f7c5ee17c3dfa43039bbc9b90d6
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ...

# %% [markdown]
# # train without checkpoint
# (only first time)

# %%
# train first time without checkpoint
# !cd $root_dir && python train.py --data_dir=$data_dir --silence_threshold=$silence_th --checkpoint_every=$d_cp --max_checkpoints=0  # keep all checkpoints
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# step 25322 - loss = 1.892, (1.375 sec/step)
# step 25323 - loss = 2.309, (0.147 sec/step)
# step 25324 - loss = 1.899, (1.367 sec/step)
# step 25325 - loss = 2.212, (0.544 sec/step)
# step 25326 - loss = 1.883, (1.377 sec/step)
# step 25327 - loss = 1.838, (0.355 sec/step)
# step 25328 - loss = 2.056, (1.370 sec/step)
# step 25329 - loss = 1.845, (0.659 sec/step)
# step 25330 - loss = 1.741, (1.380 sec/step)
# step 25331 - loss = 1.671, (0.665 sec/step)
# step 25332 - loss = 1.763, (1.387 sec/step)
# step 25333 - loss = 1.678, (0.587 sec/step)
# step 25334 - loss = 2.174, (1.397 sec/step)
# step 25335 - loss = 1.784, (0.761 sec/step)
# step 25336 - loss = 2.021, (1.386 sec/step)
# step 25337 - loss = 2.113, (0.645 sec/step)
# step 25338 - loss = 1.570, (1.390 sec/step)
# step 25339 - loss = 1.564, (0.825 sec/step)
# step 25340 - loss = 2.101, (1.381 sec/step)
# step 25341 - loss = 1.960, (0.751 sec/step)
# ...

# %% [markdown]
# # train with checkpoint

# %%
# backup logdir just in case
# !cp -r "/content/drive/MyDrive/WAVENETS/tensorflow-wavenet/logdir" "/content/drive/MyDrive/WAVENETS/.bk/logdir_bk"

# %%
# get last created folder
last_checkpoint = "/content/drive/MyDrive/WAVENETS/tensorflow-wavenet/logdir/train/2021-04-03T08-05-46"

# %%
# restore from point:
# !cd $root_dir && python train.py --data_dir=$data_dir --restore_from=$last_checkpoint --silence_threshold=$silence_th --checkpoint_every=$d_cp --max_checkpoints=0 # keep all checkpoints
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# step 95082 - loss = 1.936, (0.438 sec/step)
# step 95083 - loss = 1.587, (0.694 sec/step)
# step 95084 - loss = 1.461, (0.431 sec/step)
# step 95085 - loss = 2.092, (0.694 sec/step)
# step 95086 - loss = 1.676, (0.403 sec/step)
# step 95087 - loss = 1.693, (0.693 sec/step)
# step 95088 - loss = 1.448, (0.439 sec/step)
# step 95089 - loss = 1.461, (0.692 sec/step)
# step 95090 - loss = 1.531, (0.303 sec/step)
# step 95091 - loss = 1.524, (0.692 sec/step)
# step 95092 - loss = 1.650, (0.408 sec/step)
# step 95093 - loss = 2.018, (0.716 sec/step)
# step 95094 - loss = 2.015, (0.411 sec/step)
# step 95095 - loss = 1.744, (0.717 sec/step)
# step 95096 - loss = 1.663, (0.434 sec/step)
# step 95097 - loss = 2.285, (0.714 sec/step)
# step 95098 - loss = 1.904, (0.188 sec/step)
# step 95099 - loss = 1.514, (0.713 sec/step)
# step 95100 - loss = 1.732, (0.397 sec/step)
# step 95101 - loss = 1.505, (0.727 sec/step)
# ...
